# %%
# !pip install pandas
import pandas as pd

# %%
#Q1
#read_csv(): With the help of this funciton in pandas we are able to read and store csv files in python.
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
#head(): This function gives us by default the first 5 initial rows of a dataframe.
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#dtypes(): This function gives us the datatypes of the columns in a dataframe.
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#columns: This functions gives us all the columns present in a dataframe.
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#describe(): This function gives insigths of the data present in non-object datatype columns.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Q2
l={"A":["Alice","Bob","Claire"],"B":[25,30,27],"C":["Female","Male","Female"]}
df1=pd.DataFrame(l)
ind=list(range(1,len(df1)*2,2))
df1=pd.DataFrame(l,index=ind)
df1.head()
# Out:
#         A   B       C
# 1   Alice  25  Female
# 3     Bob  30    Male
# 5  Claire  27  Female

# %%
#Q3
sum=0
df["Values"]=[10, 20, 30, 40, 50]+list(range(886))
for i in df[(df['Values'].index)<3]['Values']:
    sum+=i
print(f"The sum of the first 3 values in the 'Values' column is {sum}")
# Out:
# The sum of the first 3 values in the 'Values' column is 60

# %%
#Q4
worl=[]
count=0
df["Text"]=df["Name"]
for i in df['Text']:
    count=len(i.split())
    worl.append(count)
    count=0

# %%
df["Word_Count"]=worl
df['Word_Count']
# Out:
# 0      4
# 1      7
# 2      3
# 3      7
# 4      4
#       ..
# 886    3
# 887    4
# 888    5
# 889    4
# 890    3
# Name: Word_Count, Length: 891, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Values  \
# 0      0         A/5 21171   7.2500   NaN        S      10
# 1      0          PC 17599  71.2833   C85        C      20
# 2      0  STON/O2. 3101282   7.9250   NaN        S      30
# 3      0            113803  53.1000  C123        S      40
# ...

# %%
#Q5
#DataFrame.size() provides the size of the dataframe by multiplying its rows with its columns.
print("Eg. DataFrame.size()")
print(df.size)
print("\n")
#DataFrame.shape() gives us the dimension of the dataframe.
print("Eg. DataFrame.shape()")
print(df.shape)
# Out:
# Eg. DataFrame.size()
# 13365
#
#
# Eg. DataFrame.shape()
# (891, 15)

# %%
#Q6
#We use pandas.read_excel() function to read excel files.

# %%
#Q7
df["Email"]='username@domain.com'
ulis=[]
for i in df["Email"]:
    ulis.append(i.split("@")[0])
df["Username"]=ulis
df[["Email","Username"]]
# Out:
#                    Email  Username
# 0    username@domain.com  username
# 1    username@domain.com  username
# 2    username@domain.com  username
# 3    username@domain.com  username
# 4    username@domain.com  username
# ..                   ...       ...
# 886  username@domain.com  username
# 887  username@domain.com  username
# 888  username@domain.com  username
# 889  username@domain.com  username
# 890  username@domain.com  username
#
# [891 rows x 2 columns]

# %%
#Q8
f1={"A":[3,8,6,2,9],"B":[5,2,9,3,1],"C":[1,7,4,5,2]}
df1=pd.DataFrame(f1)
df1
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
df1[(df1["A"]>5) & (df1["B"]<10)]
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %%
#Q9
print("Mean: ",df["Values"].mean(),"\n")
print("Median: ",df["Values"].median(),"\n")
print("Std: ",df['Values'].std(),"\n")
# Out:
# Mean:  440.18518518518516
#
# Median:  440.0
#
# Std:  257.0485121101218

# %%
#Q10
sales=list(range(1000,1012))
date=list(range(1,13))
df2=pd.DataFrame({"Sales":sales,"Date":date})
df2["MovingAverage"]=df2["Sales"].rolling(7).mean()
df2['MovingAverage']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6     1003.0
# 7     1004.0
# 8     1005.0
# 9     1006.0
# 10    1007.0
# 11    1008.0
# Name: MovingAverage, dtype: float64

# %%
#Q11
date=['2023-03-01',"2023-01-02",'2023-01-03','2023-04-04','2023-01-05']
df3=pd.DataFrame({"Date":date})
df3["Weekday"]=pd.to_datetime(df3['Date']).dt.strftime("%A")
df3
# Out:
#          Date    Weekday
# 0  2023-03-01  Wednesday
# 1  2023-01-02     Monday
# 2  2023-01-03    Tuesday
# 3  2023-04-04    Tuesday
# 4  2023-01-05   Thursday

# %%
#Q12
df3[(df3['Date']>'2023-01-01')&(df3["Date"]<"2023-01-31")]['Date']
# Out:
# 1    2023-01-02
# 2    2023-01-03
# 4    2023-01-05
# Name: Date, dtype: object

# %%
#Q13
import pandas as pd
